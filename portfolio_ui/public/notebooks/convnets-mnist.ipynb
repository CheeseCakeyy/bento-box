# %% [markdown]
# ### Discription:
# This notebook implements a Convolutional Neural Network (ConvNet) on the MNIST dataset as demonstrated in the book “Deep Learning with Python.” The code has been reproduced and executed here solely for learning and educational purposes. All original concepts and code logic belong to the book and its author, and this notebook serves only as a personal practice implementation.

# %% [markdown]
# ## Building a simple convnet:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # 0 = hide all, 1 = hide INFO, 2 = hide WARNING, 3 = hide ERROR
#The above piece of code is to hide the warnings

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(28,28,1),name='input_layer') #since out images have length and width of 28 pixals and color channels=1 since the images in MNIST are in grayscale
x = layers.Conv2D(filters=32, kernel_size=3, activation='relu') (inputs)
x = layers.MaxPooling2D(pool_size=2) (x)
x = layers.Conv2D(filters=64, kernel_size=3, activation='relu') (x)
x = layers.MaxPooling2D(pool_size=2) (x)
x = layers.Conv2D(filters=128, kernel_size=3, activation='relu') (x)
x = layers.Flatten() (x)
outputs = layers.Dense(10, activation='softmax', name='output_layer') (x)

model = keras.Model(inputs=inputs, outputs=outputs, name='ConvNet_1')
# Out:
# 2026-02-06 14:20:16.147888: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770387616.376246      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770387616.440826      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770387616.992574      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770387616.992615      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770387616.992617      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770387616.992619      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# I0000 00:00:1770387632.767478      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1770387632.773618      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
#Summerizing the model
model.summary()
# Out:
# Model: "ConvNet_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 10)             │        11,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,202 (407.04 KB)
#  Trainable params: 104,202 (407.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# *  Output of every Conv2D and MaxPooling2D layer is a rank-3 tensor of shape (height, width, channels).
# *  The width and height dimensions tend to shrink as we go deeper in the model.
# *  The first argument that is 'filters' controls the number of channels in the output of Conv2D layer.
#
# After the last Conv2D layer we have an output tensor of shape (3,3,128) but we had to feed it to our output layer which is a Densly connected layer, these layers process inputs which are 1D while we had a 3D input for it, so we flatten the 3D outputs to 1D using a *Flatten* layer, before passing it to the dense layer.
#
# Lastly a 10 way classification was done in teh output layer via a *Softmax* activation since we have 10 digit classes in the MNIST dataset.

# %% [markdown]
# ## Compiling and training the model on MNIST:
# The dataset consists of 60000 training samples and 10000 test samples

# %%
#Importing the dataset
from tensorflow.keras.datasets import mnist
(train_imgs,train_labels),(test_imgs,test_labels) = mnist.load_data()

#Scaling and reshaping the data
train_imgs = train_imgs.reshape(60000,28,28,1)
train_imgs = train_imgs.astype('float32') / 255

test_imgs = test_imgs.reshape(10000,28,28,1)
test_imgs = test_imgs.astype('float32') / 255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#compiling and training the model
model.compile(optimizer='rmsprop',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(train_imgs, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770387636.239541      69 service.cc:152] XLA service 0x7e517000a590 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1770387636.239580      69 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1770387636.239584      69 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1770387636.504247      69 cuda_dnn.cc:529] Loaded cuDNN version 91002
#  53/938 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5140 - loss: 1.4850
# I0000 00:00:1770387639.091231      69 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8841 - loss: 0.3687
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9848 - loss: 0.0478
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9898 - loss: 0.0324
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9921 - loss: 0.0238
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9951 - loss: 0.0158

# %% [markdown]
# ## Evalutating/testing the model on testdata:

# %%
test_loss, test_acc = model.evaluate(test_imgs, test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9868 - loss: 0.0458
# Test accuracy: 0.9901999831199646

# %% [markdown]
# The model achived astonishing **99.21%** accuracy on the test data, it proves that convnets are much better than a model with only Densly connected layers at compute vision tasks.
